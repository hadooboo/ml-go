// %%
import (
    "os"
    "log"
    "bytes"
    "image/color"
    
    "gonum.org/v1/plot"
    "gonum.org/v1/plot/plotter"
    "gonum.org/v1/plot/vg"
    "github.com/go-gota/gota/dataframe"
)

// %%
func displayPlot(p *plot.Plot) {
    var buf bytes.Buffer
    c, err := p.WriterTo(6*vg.Inch, 6*vg.Inch, "png")
    if err != nil {
        panic(err)
    }
    
    if _, err := c.WriteTo(&buf); err != nil {
        panic(err)
    }
    
    Display(display.PNG(buf.Bytes()))
}

// %%
f, err := os.Open("Advertising.csv")
if err != nil {
    log.Fatal(err)
}
advertDF := dataframe.ReadCSV(f)
f.Close()

// %%
yVals := advertDF.Col("Sales").Float()
pts := make(plotter.XYs, advertDF.Nrow())
ptsPred := make(plotter.XYs, advertDF.Nrow())

// %%
func predict(tv float64) float64 {
    return 7.07 + tv*0.05
}

// %%
for i, floatVal := range advertDF.Col("TV").Float() {
    pts[i].X = floatVal
    pts[i].Y = yVals[i]
    ptsPred[i].X = floatVal
    ptsPred[i].Y = predict(floatVal)
}

// %%
p := plot.New()
p.X.Label.Text = "TV"
p.Y.Label.Text = "Sales"
p.Add(plotter.NewGrid())

s, err := plotter.NewScatter(pts)
if err != nil {
    log.Fatal(err)
}
s.GlyphStyle.Color = color.RGBA{R: 255, B: 128, A: 255}
s.GlyphStyle.Radius = vg.Points(3)

l, err := plotter.NewLine(ptsPred)
if err != nil {
    log.Fatal(err)
}
l.LineStyle.Width = vg.Points(1)
l.LineStyle.Dashes = []vg.Length{vg.Points(5), vg.Points(5)}
l.LineStyle.Color = color.RGBA{B: 255, A: 255}

p.Add(s, l)

displayPlot(p)
// Out:
// [137 80 78 71 13 10 26 10 0 0 0 13 73 72 68 82 0 0 2 64 0 0 2 64 8 2 0 0 0 234 248 78 97 0 0 128 0 73 68 65 84 120 156 236 221 7 88 83 87 27 7 240 127 216 123 131 12 5 1 153 238 189 247 172 10 110 212 182 86 235 170 182 181 67 109 253 234 168 181 123 216 218 214 182 182 213 106 213 214 189 87 113 239 45 138 91 80 246 20 144 189 66 214 247 28 136 134 132 176 50 72 66 222 223 147 199 135 28 146 123 15 16 239 123 223 123 206 125 143 145 72 36 2 33 132 16 162 152 61 143 176 230 58 108 76 97 100 128 18 30 236 204 177 250 37 216 154 54 192 158 141 26 96 31 132 16 66 26 167 19 177 56 27 143 99 83 192 121 222 242 48 11 179 15 98 219 120 73 139 218 24 168 125 15 132 16 66 26 171 213 215 240 221 96 169 88 21 228 132 158 158 8 127 210 0 59 167 0 70 8 33 68 33 197 60 56 152 195 196 80 182 125 132 31 206 196 55 192 254 181 46 128 77 154 52 73 211 93 104 80 81 81 81 154 238 2 209 23 9 9 9 92 46 87 211 189 32 250 129 211 16 7 55 173 11 96 132 16 66 116 131 133 49 178 75 80 38 144 109 63 252 24 125 155 55 192 254 41 128 17 66 8 81 212 188 46 88 120 28 149 39 179 63 200 196 197 68 12 107 209 0 59 167 89 136 132 16 66 20 53 200 7 5 101 24 181 21 67 91 192 222 12 215 82 145 83 130 181 33 13 48 5 145 2 24 33 132 16 229 140 9 196 112 63 92 74 66 1 151 37 100 190 246